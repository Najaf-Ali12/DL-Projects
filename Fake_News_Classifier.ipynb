# %% [markdown]
# <a href="https://colab.research.google.com/github/Najaf-Ali12/DL-Projects/blob/main/Fake_News_Classifier.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#! pip install tensorflow

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Bidirectional
from tensorflow.keras.layers import Embedding
from tensorflow.keras.models import Sequential
from tensorflow.keras.preprocessing.text import one_hot

# %% [markdown]
# **Loading the Dataset

# %%
data=pd.read_csv("FakeNewsNet.csv")
data.head()
# Out:
#                                                title  \
# 0  Kandi Burruss Explodes Over Rape Accusation on...
# 1  People's Choice Awards 2018: The best red carp...
# 2  Sophia Bush Sends Sweet Birthday Message to 'O...
# 3  Colombian singer Maluma sparks rumours of inap...
# 4  Gossip Girl 10 Years Later: How Upper East Sid...
#
#                                             news_url        source_domain  \
# 0  http://toofab.com/2017/05/08/real-housewives-a...           toofab.com
# 1  https://www.today.com/style/see-people-s-choic...        www.today.com
# 2  https://www.etonline.com/news/220806_sophia_bu...     www.etonline.com
# 3  https://www.dailymail.co.uk/news/article-33655...  www.dailymail.co.uk
# 4  https://www.zerchoo.com/entertainment/gossip-g...      www.zerchoo.com
#
#    tweet_num  real
# 0       42.0   1.0
# 1        0.0   1.0
# 2       63.0   1.0
# 3       20.0   1.0
# 4       38.0   1.0

# %% [markdown]
# *Preprocessing*

# %%
data.columns
data.dtypes
# Out:
# title             object
# news_url          object
# source_domain     object
# tweet_num        float64
# real             float64
# dtype: object

# %%
data.isnull().sum()
# we will not remove the null values b/c we will only use title and the real column in our model which have zero null value
# Out:
# title              0
# news_url         157
# source_domain    158
# tweet_num          1
# real               1
# dtype: int64

# %%
# To check whether the outputs/data is balanced or not
data['real'].value_counts()

# We got a big issue which is imbalanced data that will compel our model to predict majority values multiple times and minority values very few times.
# Out:
# real
# 1.0    8555
# 0.0    2740
# Name: count, dtype: int64

# %% [markdown]
# ***Handling Imbalanced Data Issue***

# %%
minority_class=data[data['real']==0]
majority_class=data[data['real']==1]
print(majority_class.value_counts().sum())
print(minority_class.value_counts().sum())
# Out:
# 8521
# 2617

# %% [markdown]
# ***Resampling Techniques (using scikit-learn for basic methods) ---***
# This increases the number of samples in the minority class by randomly duplicating them.

# %%
from sklearn.utils import resample
print("OverSampling minority class")
over_sampled_minority=resample(minority_class,replace=True,n_samples=len(majority_class),random_state=42)
print(over_sampled_minority.value_counts().sum())
print(majority_class.value_counts().sum())
print(minority_class.value_counts().sum())
data.value_counts().sum()

# Resample method returns a dataframe here name is over_sampled_minority
# Out:
# OverSampling minority class
# 8174
# 8521
# 2617
# np.int64(11138)

# %%
# Concatenating over_sampled_minority and majority class to get new balanced dataframe
concatenated_df=pd.concat([majority_class,over_sampled_minority])
print(type(concatenated_df))

# Shuffling the concatenated df so that our model doesnot learn an Artificial Order
concatenated_df=concatenated_df.sample(frac=1,random_state=42).reset_index(drop=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
# Creating X and y
X=concatenated_df['title']
y=concatenated_df['real']
print(X.head())
print(y.head())
# Out:
# 0    Justin Timberlake Stops Concert for Epic Pregn...
# 1    Mandy Moore Celebrates Engagement Party With F...
# 2    Sarah Jessica Parker reflects on Sex and the C...
# 3    Angelina Jolie, Fragile At 79 Lbs, Battles Bra...
# 4    Kylie Jenner & Travis Scott Fighting Over Baby...
# Name: title, dtype: object
# 0    1.0
# 1    1.0
# 2    1.0
# 3    0.0
# 4    0.0
# Name: real, dtype: float64

# %%
import nltk
nltk.download("stopwords")
nltk.download("wordnet")
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords
import re
corpus=[]
for i in range(1,len(X)):
    review=re.sub("[^a-zA-Z]"," ",X[i])
    review=review.lower()
    review=review.split()
    # Using WordNetLemmatizer to lemmatize the words
    review=[WordNetLemmatizer().lemmatize(word) for word in review if word not in stopwords.words("english")]
    review=" ".join(review)
    corpus.append(review)

# %%
# Finding the vocabulory size
voc=[]
for each in corpus:
  for word in each.split(" "):
    if word not in voc:
      voc.append(word)
print(voc)
voc_size=len(voc)
print("Total number of unique words=",voc_size)
# Out:
# ['mandy', 'moore', 'celebrates', 'engagement', 'party', 'friend', 'pic', 'sarah', 'jessica', 'parker', 'reflects', 'sex', 'city', 'th', 'anniversary', 'angelina', 'jolie', 'fragile', 'lb', 'battle', 'brad', 'pitt', 'career', 'co', 'star', 'fear', 'fate', 'jennifer', 'aniston', 'kylie', 'jenner', 'travis', 'scott', 'fighting', 'baby', 'name', 'set', 'choice', 'pushing', 'away', 'taylor', 'momsen', 'fan', 'gather', 'mourn', 'dolores', 'riordan', 'public', 'reposal', 'move', 'aside', 'pumpkin', 'spice', 'latte', 'maple', 'pecan', 'steal', 'starbucks', 'spotlight', 'celebrity', 'join', 'tax', 'march', 'protest', 'donald', 'trump', 'russell', 'crowe', 'reveals', 'officially', 'divorced', 'danielle', 'spencer', 'jack', 'nicholson', 'michael', 'phelps', 'returning', 'swimming', 'best', 'april', 'fool', 'day', 'joke', 'mariska', 'hargitay', 'shine', 'law', 'order', 'svu', 'sneak', 'peek', 'mess', 'mama', 'bear', 'benson', 'elle', 'macpherson', 'share', 'secret', 'beauty', 'wellness', 'dry', 'brushing', 'homemade', 'granola', 'infrared', 'sauna', 'included', 'confused', 'bella', 'hadid', 'kendall', 'topless', 'thong', 'bikini', 'photo', 'anna', 'faris', 'top', 'celeb', 'mom', 'crush', 'agree', 'young', 'restless', 'actor', 'corey', 'sligh', 'convicted', 'child', 'molestation', 'pippa', 'middleton', 'wedding', 'number', 'guest', 'bottle', 'champagne', 'pricey', 'marquee', 'food', 'stamp', 'enrollment', 'drop', 'four', 'million', 'one', 'month', 'olympic', 'ice', 'dancer', 'maia', 'alex', 'shibutani', 'really', 'truly', 'like', 'compete', 'sibling', 'american', 'idol', 'renewed', 'season', 'abc', 'judge', 'host', 'ryan', 'seacrest', 'return', 'chris', 'hemsworth', 'admits', 'wife', 'sacrificed', 'lot', 'meghan', 'markle', 'make', 'royal', 'ascot', 'debut', 'carriage', 'fit', 'princess', 'quincy', 'jones', 'claim', 'dated', 'ivanka', 'year', 'ago', 'kim', 'kardashian', 'auctioning', 'clothes', 'benefit', 'hospital', 'woman', 'tv', 'series', 'nikki', 'found', 'dress', 'total', 'bellas', 'spill', 'detail', 'stunning', 'designer', 'gown', 'pregnant', 'khloe', 'show', 'bare', 'bump', 'lingerie', 'bts', 'band', 'surprise', 'high', 'school', 'student', 'prom', 'patrick', 'boll', 'arrested', 'soliciting', 'prostitution', 'sting', 'operation', 'jim', 'carrey', 'refuse', 'eat', 'isolating', 'art', 'studio', 'daphne', 'oz', 'end', 'summer', 'ruffled', 'pink', 'enters', 'third', 'trimester', 'call', 'miserable', 'bastard', 'loner', 'british', 'gq', 'breaking', 'news', 'fbi', 'uncovers', 'evidence', 'voter', 'russian', 'agent', 'justin', 'bieber', 'tour', 'cancellation', 'want', 'sustainable', 'katie', 'holmes', 'jamie', 'foxx', 'split', 'five', 'romance', 'caitlyn', 'proud', 'meeting', 'unexpected', 'approach', 'daily', 'online', 'truth', 'kate', 'relationship', 'britney', 'spear', 'angry', 'support', 'president', 'retweeted', 'cartoon', 'train', 'killing', 'cnn', 'reporter', 'miley', 'cyrus', 'liam', 'shopping', 'crib', 'josh', 'duhamel', 'gush', 'garner', 'dating', 'rumor', 'incredible', 'twilight', 'saga', 'suck', 'people', 'award', 'jackson', 'speaks', 'beyond', 'grave', 'reveal', 'death', 'kesha', 'learn', 'let', 'go', 'highlight', 'uplifting', 'method', 'moving', 'video', 'fire', 'back', 'paid', 'say', 'hardest', 'part', 'hearing', 'unnecessary', 'negativity', 'hater', 'selena', 'spend', 'thanksgiving', 'apart', 'trouble', 'paradise', 'john', 'mccain', 'jinger', 'duggar', 'give', 'birth', 'first', 'daughter', 'felicity', 'love', 'basketball', 'got', 'goosebump', 'date', 'houston', 'rocket', 'game', 'erika', 'jayne', 'talk', 'new', 'book', 'pretty', 'emma', 'stone', 'gosling', 'used', 'body', 'double', 'la', 'land', 'ed', 'sheeran', 'review', 'bland', 'everybloke', 'brings', 'pub', 'stadium', 'red', 'carpet', 'lost', 'z', 'premiere', 'theroux', 'gomez', 'sending', 'flirty', 'text', 'following', 'despite', 'report', 'sophia', 'bush', 'leaving', 'chicago', 'p', 'millie', 'bobby', 'brown', 'thousand', 'traveler', 'stranded', 'bali', 'due', 'volcan ...
# Total number of unique words= 11345

# %%
for i in range(0,5):
  print(corpus[i])
# Out:
# mandy moore celebrates engagement party friend pic
# sarah jessica parker reflects sex city th anniversary
# angelina jolie fragile lb battle brad pitt career co star fear fate jennifer aniston
# kylie jenner travis scott fighting baby name set choice pushing away
# taylor momsen

# %%
# One-Hot Encoding
one_hot_repr=[one_hot(words,voc_size) for words in corpus]
print(one_hot_repr)
# Out:
# [[4544, 7327, 3491, 2775, 7318, 1228, 7507], [7719, 4806, 4882, 7050, 4025, 3536, 2248, 3793], [1378, 8818, 1373, 385, 1219, 7692, 3411, 3908, 2798, 2717, 4373, 6873, 8195, 7556], [5164, 9371, 6205, 1023, 5457, 4284, 858, 7474, 6981, 2630, 8480], [1121, 3298], [505, 7679, 1619, 10863, 1897, 11198, 4967], [1845, 102, 9903, 4645, 3747, 2216, 9102, 3747, 6206, 9535, 6998], [1386, 6473, 7880, 868, 6612, 4505, 2810], [9389, 5330, 370, 7140, 3562, 596, 10781], [3232, 10290], [3077, 11180, 10992, 6005, 11106, 1386, 2970, 5623, 11092, 7328], [7896, 10940, 6525, 2669, 9149, 4574, 3207, 5737, 9589, 154, 10166, 6531], [9389, 308, 5592, 7900, 4866, 7168, 7716, 4071, 6919, 3320, 4107, 6266, 8064], [2873, 6324, 9869, 3578, 9371, 3940, 243, 10440, 5848], [6215, 5999, 370, 7828, 7073, 11136, 8457, 2173], [7794, 3887, 5162, 8394, 2438, 9851, 6298, 7154], [4807, 460, 6142, 6196, 1778, 11294, 6635, 9682, 9911], [2319, 7031, 7388, 2962, 8967, 6317, 8373, 8711], [9688, 7992, 10408, 6123, 6570, 10722, 6548, 8817, 10528, 6587, 1198], [4216, 9952, 2114, 6284, 280, 2402, 11093, 363, 5018, 7474, 4202], [2884, 1312, 1537, 8928, 10610, 3675, 3908], [7215, 9623, 972, 10276, 5126, 5561, 4859, 5266, 1863], [6870, 9834, 8752, 633, 7801, 2810, 2618, 9807], [5197, 3457, 5405, 11138, 7896, 6298, 10690], [4216, 2542, 5158, 1296], [6243, 6324, 8342, 6142, 7792, 929, 2130, 2717, 437, 708, 579, 7164, 1878], [10186, 3843, 3457, 6337, 10690, 4284, 2095, 3649], [1877, 7290], [5164, 9371, 10056, 6803, 2928, 10501, 2420], [5162, 3212, 5601, 9221, 4631, 250, 6505, 9089], [7177, 7612, 7808, 6121, 3021, 5334, 7265], [10186, 3944, 4938, 3491, 3507, 3285, 5693, 9760, 10440, 3090, 6353, 2392], [7692, 3411, 5300, 11148, 3576, 7216, 9220, 3743], [4361, 2342, 3215, 8282, 7879, 6317, 2810, 7322, 9802, 5693], [3045, 2458, 5392, 8638, 3035, 904], [9710, 8944, 1335, 1230, 9678, 5300, 6142, 9619, 2618, 7900, 5612], [4436, 9371, 8668, 5197, 3457, 10893, 2810], [7692, 3411, 10480, 5228, 8195, 7556, 6940, 2342, 9621], [8737, 221, 460, 7215, 9623, 1802], [6099, 1680, 1898, 6298, 10814, 1219], [1398, 4505, 2810, 10245, 829, 1768, 6822, 2650, 4969], [3058, 934, 4003, 1312, 7151, 7671], [119, 4899, 4995, 8195, 11121, 4487, 10436, 4791, 2542], [2595, 11243, 1136, 792, 6981, 8431], [3077, 1623, 10414, 5900, 7856, 10122, 8737, 1077], [1445, 11335, 7582, 1705, 5705, 5248, 6545, 4047, 7331], [7692, 3411, 4082, 8182, 1378, 8818, 8752, 4607, 6317, 6298, 10814], [5164, 9371, 3297, 8911, 4239, 4487, 9522, 5206, 653, 5088, 9621], [1069, 3045, 198, 8599, 1061, 9032, 4966], [9553, 5986, 1398], [1485, 780, 10, 8182, 10369, 6298, 1187, 4675], [10072, 8728, 5164, 9371, 11055, 1658, 6205, 1023, 7666, 7203, 3281, 316, 7507], [4115, 4301, 7963, 7406, 4013, 8697, 9589], [1682, 9820, 363, 6495, 8548, 8506, 7559, 4930, 4930, 7075], [8776, 11036, 1771, 8786, 7180, 3472, 3141, 706], [7692, 3411, 5549, 4827, 10056, 4618, 3536, 3752, 5389], [3045, 2067, 1069, 4166, 9926, 8317, 4429, 9095, 8195, 7556, 9678, 7172, 4701], [11203, 10822, 9680, 2274, 2014, 8967, 6284], [5077, 10986, 6586, 8373, 2582, 3227, 101, 7824, 5875, 5587, 4767], [9389, 5330, 7140, 4279, 596, 10781], [221, 6523, 10103, 2549], [6215, 6211, 10103, 2549], [9553, 8716, 9908, 3166, 4041, 4156, 5398, 3461, 3924], [2810, 9794, 9593, 9208], [3969, 4795, 1187, 10352, 2219, 10528, 3541, 8994, 8886, 9389, 9971], [3943, 8715, 11106, 8661, 10751, 6877, 9700, 375], [1325, 1398, 3839, 2717, 7287, 1703, 2022], [4156, 5398, 1228, 3035, 8475, 1398, 1318, 8801, 1950, 10369, 3049], [6330, 1069, 4166, 3045, 2458, 5667, 1802, 7773, 10638], [5164, 9371, 3297, 1187, 6846, 2219, 10528], [3045, 2458, 3136, 1069, 4166, 3892, 5831], [8195, 7556, 7692, 3411, 7801, 1635], [10498, 3457, 8020, 10186, 4284, 3091, 1597, 9036, 7354, 3405], [3843, 3457, 5301, 4960, 9376, 115, 1066, 7439], [4505, 1768, 2342, 4361, 9986, 10164, 6107, 635, 4599, 3130, 2740, 2810], [10951, 9952, 370, 1169, 5112, 4284, 2095], [7428, 2075, 9649, 4279], [5164, 9371, 1537, 5951, 3578, 735, 5164], [4284, 162 ...

# %%
# Finding the max length sentence in corpus
max=len(one_hot_repr[1])
for each in one_hot_repr:
  if len(each)>max:
    max=len(each)

print("The largest sentence in the corpus has",max,"words")
# Out:
# The largest sentence in the corpus has 26 words

# %%
# Padding so that values can be passed to model
from tensorflow.keras.preprocessing.sequence import pad_sequences
equal_sized_corpus=pad_sequences(one_hot_repr,padding="post",maxlen=max)
print("Equal_sized_corpus: \n")
print(equal_sized_corpus)
# Out:
# Equal_sized_corpus:
#
# [[4544 7327 3491 ...    0    0    0]
#  [7719 4806 4882 ...    0    0    0]
#  [1378 8818 1373 ...    0    0    0]
#  ...
#  [3380 9689 3232 ...    0    0    0]
#  [4806  988 6899 ...    0    0    0]
#  [1121 5984 4778 ...    0    0    0]]

# %%
# Deep learning and Model Initialization
from tensorflow.keras.layers import LSTM
model=Sequential()
model.add(Embedding(input_dim=voc_size,output_dim=20,input_length=max))
model.add(Bidirectional(LSTM(150)))
model.add(Dense(1,activation='sigmoid'))
model.build((None,20))
model.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Model: "sequential_7"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_7 (Embedding)         │ (None, 20, 20)         │       226,900 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional_3 (Bidirectional) │ (None, 300)            │       205,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │           301 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 432,401 (1.65 MB)
#  Trainable params: 432,401 (1.65 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Compiling Model
model.compile(optimizer="adam",metrics=['accuracy'],loss="categorical_crossentropy")

# %%
# Printing no of rows in X and y
print(equal_sized_corpus.shape)
print(y.shape)
# Out:
# (17109, 26)
# (17109,)

# %%
# Removing one element from y so that the no of rows in both X and y should be same
y.drop(y.iloc[0],inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-76-c407e734c983> in <cell line: 0>()
#       1 # Removing one element from y so that the no of rows in both X and y should be same
# ----> 2 y.drop(y.iloc[0],inplace=True)
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/series.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5354         dtype: float64
#    5355         """
# -> 5356         return super().drop(
#    5357             labels=labels,
#    5358             axis=axis,
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786         for axis, labels in axes.items():
#    4787             if labels is not None:
# -> 4788                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4789
#    4790         if inplace:
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors, only_slice)
#    4828                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4829             else:
# -> 4830                 new_axis = axis.drop(labels, errors=errors)
#    4831             indexer = axis.get_indexer(new_axis)
#    4832
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    7068         if mask.any():
#    7069             if errors != "ignore":
# -> 7070                 raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7071             indexer = indexer[~mask]
#    7072         return self.delete(indexer)
#
# KeyError: '[1.0] not found in axis'

# %%
# Train-test-split before training
X_train,X_test,y_train,y_test=train_test_split(equal_sized_corpus,y,test_size=0.2,random_state=42)

# %%
# Training Model
model.fit(X_train,y_train,validation_data=(X_test,y_test),epochs=20,batch_size=40)
# Out:
# Epoch 1/20
# /usr/local/lib/python3.11/dist-packages/keras/src/losses/losses.py:33: SyntaxWarning: In loss categorical_crossentropy, expected y_pred.shape to be (batch_size, num_classes) with num_classes > 1. Received: y_pred.shape=(None, 1). Consider using 'binary_crossentropy' if you only have 2 classes.
#   return self.fn(y_true, y_pred, **self._fn_kwargs)
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5058 - loss: 0.0000e+00
# /usr/local/lib/python3.11/dist-packages/keras/src/losses/losses.py:33: SyntaxWarning: In loss categorical_crossentropy, expected y_pred.shape to be (batch_size, num_classes) with num_classes > 1. Received: y_pred.shape=(None, 1). Consider using 'binary_crossentropy' if you only have 2 classes.
#   return self.fn(y_true, y_pred, **self._fn_kwargs)
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 7s 11ms/step - accuracy: 0.5058 - loss: 0.0000e+00 - val_accuracy: 0.4863 - val_loss: 0.0000e+00
# Epoch 2/20
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.5043 - loss: 0.0000e+00 - val_accuracy: 0.4863 - val_loss: 0.0000e+00
# Epoch 3/20
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - accuracy: 0.5043 - loss: 0.0000e+00 - val_accuracy: 0.4863 - val_loss: 0.0000e+00
# Epoch 4/20
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.5032 - loss: 0.0000e+00 - val_accuracy: 0.4863 - val_loss: 0.0000e+00
# Epoch 5/20
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - accuracy: 0.5009 - loss: 0.0000e+00 - val_accuracy: 0.4863 - val_loss: 0.0000e+00
# Epoch 6/20
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - accuracy: 0.5023 - loss: 0.0000e+00 - val_accuracy: 0.4863 - val_loss: 0.0000e+00
# Epoch 7/20
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.4985 - loss: 0.0000e+00 - val_accuracy: 0.4863 - val_loss: 0.0000e+00
# Epoch 8/20
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.5003 - loss: 0.0000e+00 - val_accuracy: 0.4863 - val_loss: 0.0000e+00
# Epoch 9/20
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.5053 - loss: 0.0000e+00 - val_accuracy: 0.4863 - val_loss: 0.0000e+00
# Epoch 10/20
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.5067 - loss: 0.0000e+00 - val_accuracy: 0.4863 - val_loss: 0.0000e+00
# Epoch 11/20
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.5011 - loss: 0.0000e+00 - val_accuracy: 0.4863 - val_loss: 0.0000e+00
# Epoch 12/20
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.5043 - loss: 0.0000e+00 - val_accuracy: 0.4863 - val_loss: 0.0000e+00
# Epoch 13/20
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.5080 - loss: 0.0000e+00 - val_accuracy: 0.4863 - val_loss: 0.0000e+00
# Epoch 14/20
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - accuracy: 0.4997 - loss: 0.0000e+00 - val_accuracy: 0.4863 - val_loss: 0.0000e+00
# Epoch 15/20
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.5004 - loss: 0.0000e+00 - val_accuracy: 0.4863 - val_loss: 0.0000e+00
# Epoch 16/20
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.5029 - loss: 0.0000e+00 - val_accuracy: 0.4863 - val_loss: 0.0000e+00
# Epoch 17/20
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.5069 - loss: 0.0000e+00 - val_accuracy: 0.4863 - val_loss: 0.0000e+00
# Epoch 18/20
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.5078 - loss: 0.0000e+00 - val_accuracy: 0.4863 - val_loss: 0.0000e+00
# Epoch 19/20
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.5018 - loss: 0.0000e+00 - val_accuracy: 0.4863 - val_loss: 0.0000e+00
# Epoch 20/20
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.5055 - loss: 0.0000e+00 - val_accuracy: 0.4863 - val_loss: 0.0000e+00

# %%
# Predication
y_pred=model.predict(X_test)
# Out:
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step

# %%
# Accuracy score of model
accuracy=accuracy_score(y_test,y_pred.round())
print("Accuracy of model=",accuracy)
# Out:
# Accuracy of model= 0.4862653419053185

# %%
# Confusion matrix
confusion_matrix(y_test,y_pred.round())
# Out:
# array([[1664,    0],
#        [1758,    0]])

# %%
# Classification report
print(classification_report(y_test,y_pred.round()))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.49      1.00      0.65      1664
#          1.0       0.00      0.00      0.00      1758
#
#     accuracy                           0.49      3422
#    macro avg       0.24      0.50      0.33      3422
# weighted avg       0.24      0.49      0.32      3422
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
